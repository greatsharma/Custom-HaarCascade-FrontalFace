# %%
import os
import cv2
import shutil
from zipfile import ZipFile

# %%
try:
    shutil.rmtree("sample_data")
except Exception:
    pass

# %%
with ZipFile("drive/My Drive/custom_haarcascades/neg.zip", 'r') as zip_:
    print('Extracting...') 
    zip_.extractall()
    print('Done!')

with ZipFile("drive/My Drive/custom_haarcascades/frontal_face/pos.zip", 'r') as zip_:
    print('Extracting...') 
    zip_.extractall()
    print('Done!')
# Out:
# Extracting...
# Done!
# Extracting...
# Done!

# %%
! mkdir data

# %%
! touch bg.txt

# %%
count = 0
for img in os.listdir("neg/"):
    line = "neg/" + img + "\n"
    with open("bg.txt", "a") as f:
        f.write(line)
    count += 1

count
# Out:
# 2734

# %%
! touch pos.info

# %%
count = 0
for img in os.listdir("pos/"):
    count += 1
    im = cv2.imread("pos/"+img, 0)
    line = "pos/" + img + " 1 0 0 96 96\n"

    with open("pos.info", "a") as f:
        f.write(line)

count
# Out:
# 6190

# %%
! opencv_createsamples -info pos.info -num 6100 -w 25 -h 25 -vec pos.vec
# Out:
# Info file name: pos.info
# Img file name: (NULL)
# Vec file name: pos.vec
# BG  file name: (NULL)
# Num: 6100
# BG color: 0
# BG threshold: 80
# Invert: FALSE
# Max intensity deviation: 40
# Max x angle: 1.1
# Max y angle: 1.1
# Max z angle: 0.5
# Show samples: FALSE
# Width: 25
# Height: 25
# Max Scale: -1
# Create training samples from images collection...
# Done. Created 6100 samples

# %%
# ! mkdir data

# %%
# %%time

! opencv_traincascade -data data -vec pos.vec -bg bg.txt -numPos 2400 -numNeg 2730 -numStages 20 -w 25 -h 25 -numThreads 2 -precalcValBufSize 5120 -precalcIdxBufSize 5120
# Out:
# PARAMETERS:
# cascadeDirName: data
# vecFileName: pos.vec
# bgFileName: bg.txt
# numPos: 2400
# numNeg: 2730
# numStages: 20
# precalcValBufSize[Mb] : 5120
# precalcIdxBufSize[Mb] : 5120
# acceptanceRatioBreakValue : -1
# stageType: BOOST
# featureType: HAAR
# sampleWidth: 25
# sampleHeight: 25
# boostType: GAB
# minHitRate: 0.995
# maxFalseAlarmRate: 0.5
# weightTrimRate: 0.95
# maxDepth: 1
# maxWeakCount: 100
# mode: BASIC
# Number of unique features given windowSize [25,25] : 190736
#
# ===== TRAINING 0-stage =====
# <BEGIN
# POS count : consumed   2400 : 2400
# NEG count : acceptanceRatio    2730 : 1
# tcmalloc: large alloc 3913908224 bytes == 0x55e4e60b8000 @  0x7f8ff8dba1e7 0x7f8ff7f8d382 0x7f8ff808c21b 0x55e4de2f8608 0x55e4de2f8d42 0x55e4de2f8e1a 0x55e4de3021a9 0x55e4de2eefff 0x7f8ff7250b97 0x55e4de2efc1a
# ...
